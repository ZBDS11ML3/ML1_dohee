# %%
# %pip install Librosa
# Out:
# Collecting Librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib>=0.14 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (1.2.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (5.1.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.4-cp38-cp38-macosx_11_0_arm64.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.0/382.0 kB 4.2 MB/s eta 0:00:0000:0100:01
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 4.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (4.4.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (1.10.0)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.3 MB/s eta 0:00:00:00:0100:01
# Collecting numba>=0.51.0
#   Downloading numba-0.56.4-cp38-cp38-macosx_11_0_arm64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Collecting msgpack>=1.0
#   Downloading msgpack-1.0.5-cp38-cp38-macosx_11_0_arm64.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from Librosa) (1.23.5)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp38-cp38-macosx_11_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 10.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: importlib-metadata in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from numba>=0.51.0->Librosa) (6.0.0)
# Requirement already satisfied: setuptools in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from numba>=0.51.0->Librosa) (67.1.0)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from pooch<1.7,>=1.0->Librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from pooch<1.7,>=1.0->Librosa) (2.28.2)
# Requirement already satisfied: packaging>=20.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from pooch<1.7,>=1.0->Librosa) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from scikit-learn>=0.20.0->Librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from soundfile>=0.12.1->Librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->Librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->Librosa) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->Librosa) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->Librosa) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->Librosa) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->Librosa) (3.12.0)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23704 sha256=b1fbc00f2d4d5a2f7d51bf1b6bd7f7588e89bc58c0eef2995863e4f1c230cd6a
#   Stored in directory: /Users/dohee/Library/Caches/pip/wheels/0a/ed/be/49df2538fca496690a024a4374455584d65c2afd6fc3d6e9c7
# Successfully built audioread
# Installing collected packages: msgpack, soxr, llvmlite, lazy-loader, audioread, soundfile, numba, Librosa
# Successfully installed Librosa-0.10.0.post2 audioread-3.0.0 lazy-loader-0.2 llvmlite-0.39.1 msgpack-1.0.5 numba-0.56.4 soundfile-0.12.1 soxr-0.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_path = '/Users/dohee/Documents/ds_study/ML_project1/genres/blues/blues.00000.au'
y, sr = librosa.load(audio_path)

# %%
len(y)
# Out:
# 661794

# %%
sr
# Out:
# 22050

# %%
stft_result = librosa.stft(y, n_fft=4096, win_length = 4096, hop_length=1024)
D = np.abs(stft_result)
S_dB = librosa.power_to_db(D, ref=np.max)
librosa.display.specshow(S_dB, sr=sr, hop_length = 1024, y_axis='linear', x_axis='time')
plt.colorbar(format='%2.0f dB')
plt.show()

# %%
print(D.shape)

plt.figure(figsize=(16,6))
plt.plot(D)
plt.show()
# Out:
# (2049, 647)

# %%
D
# Out:
# array([[3.8052719e+00, 5.4961381e+00, 4.9718833e+00, ..., 7.3253192e-02,
#         1.0490617e-01, 8.6996784e+00],
#        [2.9052718e+00, 2.6022561e+00, 3.3773587e+00, ..., 3.6240003e+00,
#         5.9717731e+00, 1.1113605e+01],
#        [1.6741936e+00, 7.5236773e-01, 1.1717750e+00, ..., 9.6892750e-01,
#         5.9348903e+00, 1.2644771e+01],
#        ...,
#        [2.8070071e-04, 2.0114025e-04, 8.1724807e-05, ..., 2.4654198e-04,
#         7.5325090e-03, 2.4414079e-02],
#        [2.8876294e-04, 1.8875106e-04, 1.4931649e-04, ..., 4.9598451e-04,
#         7.2378018e-03, 2.4108140e-02],
#        [2.2461782e-04, 3.1297359e-06, 2.7920989e-06, ..., 2.5547793e-04,
#         6.8074721e-03, 2.3762558e-02]], dtype=float32)

# %%
S_dB
# Out:
# array([[-19.246582, -17.64986 , -18.085228, ..., -36.402172, -34.842426,
#         -15.655406],
#        [-20.41857 , -20.896938, -19.764666, ..., -19.458555, -17.289406,
#         -14.591888],
#        [-22.812382, -26.286137, -24.361996, ..., -25.187525, -17.31631 ,
#         -14.031328],
#        ...,
#        [-60.568   , -62.01545 , -65.926895, ..., -61.13153 , -46.28104 ,
#         -41.174034],
#        [-60.445023, -62.291542, -63.30936 , ..., -58.095757, -46.45437 ,
#         -41.2288  ],
#        [-61.535995, -80.      , -80.      , ..., -60.976906, -46.72058 ,
#         -41.291504]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize =(16,6))
librosa.display.waveshow(y=y,sr=sr)
plt.show()

# %%
fft = np.fft()

# %%
S = librosa.feature.melspectrogram(y=y,sr=sr)
S_DB = librosa.amplitude_to_db(S, ref=np.max)

plt.figure(figsize=(16,6))
librosa.display.specshow(S_DB, sr=sr,hop_length=512, x_axis='time',y_axis='log')
plt.colorbar()
plt.show()
