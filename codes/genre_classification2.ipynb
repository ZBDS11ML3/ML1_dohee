# %%
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
import os
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
df_all = pd.read_csv("/Users/dohee/Documents/ds_study/ML_project1/datas/features_3_sec.csv")

# %%
df_all.columns
# Out:
# Index(['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
#        'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
path_entersandman = "/Users/dohee/Documents/ds_study/data/new_musics/Metallica Enter Sandman (Official Music Video).wav"
y, sr = librosa.load(path_entersandman)
dur = librosa.get_duration(y=y, sr=sr)
dur
n=5
start = 0
tmp = []

for k in range(0, int(dur//n)):
    new_y, new_sr = librosa.load(path_entersandman,offset=start,duration=n)
    path = path_entersandman
    name = f"{k}"
    chroma_stft = np.mean(librosa.feature.chroma_stft(y=new_y, sr=new_sr))
    chroma_stft_var = np.var(librosa.feature.chroma_stft(y=new_y, sr=new_sr))
    rmse = np.mean(librosa.feature.rms(y=new_y))
    rmse_var = np.var(librosa.feature.rms(y=new_y))
    tmp.append({
    "chroma_stft":chroma_stft,
    "rmse":rmse,
    "chroma_stft_var":chroma_stft_var,
    "rmse_var":rmse_var
    })
    start += n

tmp
# Out:
# /var/folders/l4/c_yyc4653dzbw_s9qxhd31000000gn/T/ipykernel_69952/447268227.py:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(path_entersandman)
# /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# /var/folders/l4/c_yyc4653dzbw_s9qxhd31000000gn/T/ipykernel_69952/447268227.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   new_y, new_sr = librosa.load(path_entersandman,offset=start,duration=n)
# [{'chroma_stft': 0.49489456,
#   'rmse': 0.033129267,
#   'chroma_stft_var': 0.09934941,
#   'rmse_var': 0.0013561875},
#  {'chroma_stft': 0.27918664,
#   'rmse': 0.071939014,
#   'chroma_stft_var': 0.0883559,
#   'rmse_var': 0.00015652637},
#  {'chroma_stft': 0.31367275,
# ...

# %%
dur//5
# Out:
# 66.0

# %%
df_tmp = pd.DataFrame(tmp)
df_tmp
# Out:
#     chroma_stft      rmse  chroma_stft_var  rmse_var
# 0      0.494895  0.033129         0.099349  0.001356
# 1      0.279187  0.071939         0.088356  0.000157
# 2      0.313673  0.069732         0.082097  0.000181
# 3      0.353045  0.107873         0.088503  0.004099
# 4      0.536327  0.200607         0.064369  0.002061
# ..          ...       ...              ...       ...
# 61     0.477378  0.241423         0.069769  0.001461
# 62     0.474649  0.131746         0.070999  0.001069
# 63     0.477495  0.065077         0.074691  0.000328
# 64     0.483056  0.029252         0.069251  0.000059
# 65     0.478968  0.009321         0.076877  0.000030
#
# [66 rows x 4 columns]

# %%
import librosa
path_entersandman = "/Users/dohee/Documents/ds_study/data/new_musics/Metallica Enter Sandman (Official Music Video).wav"
y, sr = librosa.load(path_entersandman,offset=0,duration=5)
# Out:
# /var/folders/l4/c_yyc4653dzbw_s9qxhd31000000gn/T/ipykernel_69952/733531525.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(path_entersandman,offset=0,duration=5)

# %%
y
# Out:
# array([-4.3490490e-06, -1.1337674e-05,  8.4626599e-06, ...,
#        -7.2847977e-02, -6.5829150e-02, -7.1554460e-02], dtype=float32)

# %%
ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import genre_transition as gt 
path_entersandman = "/Users/dohee/Documents/ds_study/data/new_musics/Metallica Enter Sandman (Official Music Video).wav"
feature_exed = gt.feature_extraction(path_entersandman, file_name="Enter Sandman",n=5)
feature_exed = pd.DataFrame(feature_exed)
feature_exed
# Out:
# /Users/dohee/Documents/ds_study/ML_project1/codes/genre_transition.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path)
# /Users/dohee/miniforge3/envs/ds_study/lib/python3.8/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# /Users/dohee/Documents/ds_study/ML_project1/codes/genre_transition.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   new_y, new_sr = librosa.load(file_path,offset=start,duration=n)
# /Users/dohee/Documents/ds_study/ML_project1/codes/genre_transition.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   new_y, new_sr = librosa.load(file_path,offset=start,duration=n)
# ...

# %%
X = df_all.drop(labels=['path','filename','label'],axis=1)
X
